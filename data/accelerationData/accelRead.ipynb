# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
genAccel = pd.read_csv("accelData.csv")

genAccel.head()
x = genAccel['x']
y = genAccel[' y']
z = genAccel[' z']
t = [i for i in range(genAccel.shape[0])]

# %%
plt.plot(t,x,'b')
plt.plot(t,y,'g')
plt.plot(t,z,'r')

# %%
forwardAccel = pd.read_csv('accelDataForward.csv')
xf = forwardAccel['x']
yf = forwardAccel[' y']
zf = forwardAccel[' z']
tf = [i for i in range(forwardAccel.shape[0])]

# %%
plt.plot(tf,xf,'b')
plt.plot(tf,yf,'g')
plt.plot(tf,zf,'r')

# %%
sideAccel = pd.read_csv('accelDataSide.csv')
xs = sideAccel['x']
ys = sideAccel[' y']
zs = sideAccel[' z']
ts = [i for i in range(sideAccel.shape[0])]

# %%
plt.plot(ts,xs,'b')
plt.plot(ts,ys,'g')
plt.plot(ts,zs,'r')

# %%
upAccel = pd.read_csv('accelDataUpDown.csv')
xu = upAccel['x']
yu = upAccel[' y']
zu = upAccel[' z']
tu = [i for i in range(upAccel.shape[0])]

# %%
plt.plot(tu,xu,'b')
plt.plot(tu,yu,'g')
plt.plot(tu,zu,'r')

# %%
flipAccel = pd.read_csv('accelDataflip.csv')
fx = flipAccel['x']
fy = flipAccel['y']
fz = flipAccel['z']
ft = [i for i in range(flipAccel.shape[0])]

# %%
plt.plot(ft,fx,'b')
plt.plot(ft,fy,'g')
plt.plot(ft,fz,'r')

# %%
flickAccel = pd.read_csv('accelDataflick.csv')
flx = flipAccel['x']
fly = flipAccel['y']
flz = flipAccel['z']
flt = [i for i in range(flx.shape[0])]

# %%
plt.plot(flt,flx,'b')
plt.plot(flt,fly,'g')
plt.plot(flt,flz,'r')

# %%
flickDown = pd.read_csv('accelDataflickDown.csv')
fldx = flickDown['x']
fldy = flickDown['y']
fldz = flickDown['z']
fldt = [i for i in range(fldx.shape[0])]

# %%
plt.plot(fldt,fldx,'b')
plt.plot(fldt,fldy,'g')
plt.plot(fldt,fldz,'r')

# %%
flickHold = pd.read_csv('accelDataFlickHold.csv')
flhx = flickHold['x']
flhy = flickHold['y']
flhz = flickHold['z']
flht = [i for i in range(flhx.shape[0])]

# %%
plt.plot(flht,flhx,'b')
plt.plot(flht,flhy,'g')
plt.plot(flht,flhz,'r')

# %%
flickSlowHold = pd.read_csv('accelDataHoldTime.csv')
flsx = flickSlowHold['x']
flsy = flickSlowHold['y']
flsz = flickSlowHold['z']
flst = [i for i in range(flsx.shape[0])]

# %%
plt.plot(flst,flsx,'b')
plt.plot(flst,flsy,'g')
plt.plot(flst,flsz,'r')
