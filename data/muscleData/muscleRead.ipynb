# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
snap0 = pd.read_csv('snap.csv')
y = snap0['emg']
x = [i for i in range(y.shape[0])]
plt.plot(x,y)

# %%
snap2 = pd.read_csv('snap2.csv')
y2 = snap2['emg']
x2 = [i for i in range(y2.shape[0])]
plt.plot(x2,y2)

# %%
snap3 = pd.read_csv('snap3.csv')
y3 = snap3['emg']
x3 = [i for i in range(y3.shape[0])]
plt.plot(x3,y3)

# %%
snap4 = pd.read_csv('snap4.csv')
y4 = snap4['emg']
x4 = [i for i in range(y4.shape[0])]
plt.plot(x4,y4)
